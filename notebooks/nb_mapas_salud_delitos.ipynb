# %%
import pandas as pd
import numpy as np

# %%
final = pd.read_excel('Health_crime_dta.xlsx' )
final
# Out:
#         Unnamed: 0  anio   id_hogar cod_resultado  cod_persona    sexo  edad  \
# 0                0  2019     100201      completa            2   mujer    33
# 1                1  2019     102801      completa            2   mujer    36
# 2                2  2019     104801      completa            2   mujer    28
# 3                3  2019     113601      completa            2   mujer    30
# 4                4  2019     116701      completa            1   mujer    18
# ...            ...   ...        ...           ...          ...     ...   ...
# 140826      140826  2023  542706001      completa            1  hombre    60
# 140827      140827  2023  542707401      completa            1  hombre    47
# 140828      140828  2023  542708901      completa            1  hombre    47
# 140829      140829  2023  542709201      completa            2   mujer    38
# 140830      140830  2023  542709401      completa            1  hombre    55
#
# ...

# %%
final = final.drop(columns=['Unnamed: 0'])
final
# Out:
#         anio   id_hogar cod_resultado  cod_persona    sexo  edad  media_sis  \
# 0       2019     100201      completa            2   mujer    33        100
# 1       2019     102801      completa            2   mujer    36        110
# 2       2019     104801      completa            2   mujer    28        134
# 3       2019     113601      completa            2   mujer    30         98
# 4       2019     116701      completa            1   mujer    18        118
# ...      ...        ...           ...          ...     ...   ...        ...
# 140826  2023  542706001      completa            1  hombre    60        139
# 140827  2023  542707401      completa            1  hombre    47        121
# 140828  2023  542708901      completa            1  hombre    47        125
# 140829  2023  542709201      completa            2   mujer    38        120
# 140830  2023  542709401      completa            1  hombre    55        125
#
# ...
